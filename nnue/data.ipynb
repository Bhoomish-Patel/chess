# %%
with open("/Users/fds48568/Desktop/chess/nnue/test80-2024-01-jan-2tb7p.min-v2.v6.binpack","rb") as f:
    text = f.readline(90)
print(text)
# Out:
# b'BINP\x07\x00\x10\x00\xff\xff\x00\x00\x00\x00\xff\xff-\x84J\xd2\x00\x00\x00\x00\x11\x11\x11\x11>\x95[\xe3\x0bl\xfa\x04\x00\x00\x00\x00\x00k6;\x97\xeaB\xe5\x8dj\n'

# %%
text = text[4:]
text
# Out:
# b'\x07\x00\x10\x00\xff\xff\x00\x00\x00\x00\xff\xff-\x84J\xd2\x00\x00\x00\x00\x11\x11\x11\x11>\x95[\xe3\x0bl\xfa\x04\x00\x00\x00\x00\x00k6;\x97\xeaB\xe5\x8dj\n'

# %%
stem = text[:32]
stem
# Out:
# b'\x07\x00\x10\x00\xff\xff\x00\x00\x00\x00\xff\xff-\x84J\xd2\x00\x00\x00\x00\x11\x11\x11\x11>\x95[\xe3\x0bl\xfa\x04'

# %%
pos = stem[:24]
int.from_bytes(pos,"big")
# Out:
# 171645488349165396100197409146169860751007503558185652497

# %%
move = stem[24:26]
int.from_bytes(move,"big")
# Out:
# 16021
